# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process as fuzz_process

# import os
# import warnings

# import numpy as np

import pickle
import pandas as pd
# pd.set_option("display.max_columns", 50)
import matplotlib.pyplot as plt
# %matplotlib inline
# import networkx as nx

# from . import utils
# import utils
from utils import *

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df_stops = filter_stops_by_distance_from_zurich_hb(load_df_stops(), 1000)
df_stops
# Out:
#                               stop_name   latitude  longitude
# stop_id
# 8503000                       Zürich HB  47.378176   8.540212
# 8503010                     Zürich Enge  47.364098   8.530824
# 8503011                 Zürich Wiedikon  47.371478   8.523485
# 8503088                   Zürich HB SZU  47.377428   8.539169
# 8503090                   Zürich Selnau  47.372239   8.531722
# 8503447                 Zürich Storchen  47.371028   8.541963
# 8506517              Zürich, Hertersteg  47.367682   8.522991
# 8507183      Zürich, Kantonsschule Enge  47.364238   8.527509
# 8530822               Zürich Limmatquai  47.373018   8.542637
# 8573710        Zürich Wiedikon, Bahnhof  47.371430   8.524186
# 8587348         Zürich, Bahnhofplatz/HB  47.377239   8.539340
# 8587349          Zürich, Bahnhofquai/HB  47.377562   8.541739
# 8591052            Zürich, Bäckeranlage  47.378669   8.523108
# 8591058            Zürich Enge, Bahnhof  47.364129   8.531570
# 8591059  Zürich Enge, Bahnhof/Bederstr.  47.364555   8.530456
# 8591064          Zürich Selnau, Bahnhof  47.370669   8.532010
# 8591067       Zürich, Bahnhofstrasse/HB  47.376224   8.539457
# 8591079          Zürich, Bezirksgebäude  47.374167   8.525560
# 8591093            Zürich, Kantonalbank  47.368169   8.539744
# 8591105             Zürich, Bürkliplatz  47.366538   8.540786
# 8591183                Zürich, Helmhaus  47.370073   8.543293
# 8591184           Zürich, Helvetiaplatz  47.376357   8.525362
# 8591218  Zürich,Kalkbreite/Bhf.Wiedikon  47.374423   8.521338
# 8591219            Zürich, Kanonengasse  47.378468   8.530303
# 8591227             Zürich, Kernstrasse  47.374508   8.524266
# 8591262              Zürich, Löwenplatz  47.375895   8.537418
# 8591277    Zürich, Militär-/Langstrasse  47.379600   8.527626
# 8591299             Zürich, Paradeplatz  47.369732   8.538918
# 8591309                 Zürich, Rathaus  47.371740   8.542880
# 8591316                 Zürich, Rennweg  47.373066   8.538460
# 8591327      Zürich, Rudolf-Brun-Brücke  47.373948   8.542933
# 8591341       Zürich, Schmiede Wiedikon  47.370152   8.519263
# 8591367             Zürich, Sihlpost/HB  47.376096   8.534202
# 8591368             Zürich, Sihlquai/HB  47.379873   8.537606
# 8591369             Zürich, Sihlstrasse  47.372269   8.534570
# 8591381             Zürich, Stauffacher  47.373425   8.529252
# 8591384          Zürich, Stockerstrasse  47.367871   8.535424
# 8591404           Zürich, Tunnelstrasse  47.366143   8.532531
# 8591427                    Zürich, Werd  47.372324   8.526845
# 8503088                   Zürich HB SZU  47.377391   8.539358

# %%
fuzzy_search_stops(df_stops, 'Zürich Trie')
# Out:
#                  stop_name   latitude  longitude  ratio
# stop_id
# 8503054     Zürich Triemli  47.364993   8.495377     88
# 8503610    Zürich, Triemli  47.368150   8.495377     85
# 8587652    Zürich, Altried  47.405628   8.591002     77
# 8591190    Zürich, Heuried  47.369410   8.506354     77
# 8591104   Zürich, Burgwies  47.358019   8.571868     74
# ...                    ...        ...        ...    ...
# 8590699  Kloten, Stadthaus  47.451261   8.581103      7
# 8502758               Post  47.244748   8.532980      0
# 8502758               Post  47.244748   8.532971      0
# 8503303             Illnau  47.408820   8.722731      0
# 8503062                Egg  47.301499   8.689610      0
#
# [1626 rows x 4 columns]

# %%
# connections_df = utils.load_stop_times()
# edges_df = connections_df[['dep_stop_id', 'arr_stop_id']]
# edges_df = edges_df.drop_duplicates()
# edges_df
# edges_df.merge(df_stops, left_on='dep_stop_id', right_on='stop_id')

# %%
# df_walks = pd.read_csv(PATH_WALK_EDGES_15K)

df_walks = filter_connections_by_stops(load_df_walks(), df_stops)
df_walks
# Out:
#      dep_stop_id  weight  arr_stop_id
# 0        8503000     137      8503088
# 1        8503000     169      8503446
# 2        8503000     409      8503499
# 3        8503000     587      8503500
# 4        8503000     147      8587348
# ..           ...     ...          ...
# 394      8591427     272      8591079
# 395      8591427     554      8591184
# 396      8591427     572      8591218
# 397      8591427     373      8591227
# 398      8591427     263      8591381
#
# [399 rows x 3 columns]
